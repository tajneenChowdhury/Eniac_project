# %% [markdown]
# # **Project**
# **Case Study: Eniac's Discount Strategy**

# %% [markdown]
# #Importing libery

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Loading Data

# %%
url = 'https://drive.google.com/file/d/1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders_df_original = pd.read_csv(path)

# %%
url = 'https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orderlines_df_original = pd.read_csv(path)

# %%
url = 'https://drive.google.com/file/d/1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
products_df_original = pd.read_csv(path)

# %%
url = 'https://drive.google.com/file/d/1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brands_df_original = pd.read_csv(path)

# %%
#making a copy of all dataframes
orders_df = orders_df_original.copy()
orderlines_df = orderlines_df_original.copy()
products_df = products_df_original.copy()
brands_df = brands_df_original.copy()

# %% [markdown]
# #Initial Data Exploration

# %% [markdown]
# ##Brands

# %%
brands_df.head()
# Out:
#   short       long
# 0   8MO  8Mobility
# 1   ACM       Acme
# 2   ADN     Adonit
# 3   AII      Aiino
# 4   AKI     Akitio

# %%
brands_df.shape

print(f"The number of rows is: {brands_df.shape[0]}")
print(f"†he number of columns is:{brands_df.shape[1]}")
# Out:
# The number of rows is: 187
# †he number of columns is:2

# %%
brands_df.size
# Out:
# 374

# %%
brands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.1+ KB

# %%
brands_df.describe()
# Out:
#        short   long
# count    187    187
# unique   187    181
# top      8MO  Apple
# freq       1      2

# %%
brands_df.nunique()
# Out:
# short    187
# long     181
# dtype: int64

# %%
brands_df.isna().sum()
# Out:
# short    0
# long     0
# dtype: int64

# %%
brands_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#For identifying any pattern:
# a) string length in "short" ( All strings are of 3 & alphanumeric)

#brands_df['short'].str.len()
brands_df['short'].str.len().unique()
# Out:
# array([3])

# %%
# b) string length in "long" (All strings length varies from 2-16 & alphanumeric)

#brands_df['long'].str.len()
brands_df['long'].str.len().unique()
# Out:
# array([ 9,  4,  6,  5, 10, 16,  8,  7,  3, 13, 12, 11, 15,  2])

# %% [markdown]
# ##orders

# %%
orders_df.head()
# Out:
#    order_id         created_date  total_paid      state
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled
# 1    241423  2017-11-06 13:10:02      136.15  Completed
# 2    242832  2017-12-31 17:40:03       15.76  Completed
# 3    243330  2017-02-16 10:59:38       84.98  Completed
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled

# %%
orders_df.shape

print(f"The number of rows is: {orders_df.shape[0]}")
print(f"†he number of columns is:{orders_df.shape[1]}")
# Out:
# The number of rows is: 226909
# †he number of columns is:4

# %%
orders_df.size
# Out:
# 907636

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %%
orders_df.describe().round(2)
# Out:
#         order_id  total_paid
# count  226909.00   226904.00
# mean   413296.48      569.23
# std     65919.25     1761.78
# min    241319.00        0.00
# 25%    356263.00       34.19
# 50%    413040.00      112.99
# 75%    470553.00      525.98
# max    527401.00   214747.53

# %%
orders_df.nunique()
# Out:
# order_id        226909
# created_date    224828
# total_paid       31236
# state                5
# dtype: int64

# %%
#to identify in different distribution pattern
orders_df['total_paid'].agg(['mean','median']).round(2)
# Out:
# mean      569.23
# median    112.99
# Name: total_paid, dtype: float64

# %%
orders_df.isna().sum()
# Out:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64

# %%
orders_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#for identify any pattern

#orders_df.loc[orders_df['total_paid']==0,:]
#orders_df.total_paid.nunique()
orders_df['total_paid'].value_counts().sort_values(ascending=False)
# Out:
# total_paid
# 0.00       19334
# 19.99       2812
# 29.99       2193
# 39.99       1504
# 49.99       1495
#            ...
# 1311.92        1
# 66.55          1
# 158.83         1
# 3070.82        1
# 243.90         1
# Name: count, Length: 31236, dtype: int64

# %%
completed_order =orders_df.loc[(orders_df['state']== 'Completed') & (orders_df['total_paid']==0)]
completed_order
# Out:
#         order_id         created_date  total_paid      state
# 150       296010  2017-01-09 23:47:00         0.0  Completed
# 2061      301495  2017-01-03 12:22:02         0.0  Completed
# 30427     329911  2017-02-27 18:21:01         0.0  Completed
# 61224     360765  2017-05-30 23:28:57         0.0  Completed
# 61902     361443  2017-06-01 23:21:54         0.0  Completed
# 61977     361518  2017-06-02 06:18:27         0.0  Completed
# 63610     363153  2017-06-07 13:39:13         0.0  Completed
# 65940     365485  2017-06-14 10:37:02         0.0  Completed
# 82898     382473  2017-07-26 18:23:09         0.0  Completed
# 82938     382513  2017-07-26 19:23:21         0.0  Completed
# 83327     382902  2017-07-28 16:37:37         0.0  Completed
# 84934     384509  2017-07-31 17:01:12         0.0  Completed
# 98470     398054  2017-09-09 00:14:12         0.0  Completed
# 106762    406347  2017-09-30 11:39:42         0.0  Completed
# ...

# %% [markdown]
# **Observation and Action**
#
# *Created_date: should be date format
# *Total_paid:
# 1.   Missing Value
# 2.   mean-median is gap is high (569.23-112.99), so extreme value outliers. Also 75% of orders are for 525.98 or less , while the max value is 214,747.53
#
# 3. 0.0 values for 19334

# %% [markdown]
# ##orderlines

# %%
orderlines_df.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40
# 4  2017-01-01 01:06:38

# %%
orderlines_df.shape

print(f"The number of rows is: {orderlines_df.shape[0]}")
print(f"†he number of columns is:{orderlines_df.shape[1]}")
# Out:
# The number of rows is: 293983
# †he number of columns is:7

# %%
orderlines_df.size
# Out:
# 2057881

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %%
orderlines_df.describe().round(2)
# Out:
#                id   id_order  product_id  product_quantity
# count   293983.00  293983.00    293983.0         293983.00
# mean   1397918.10  419999.12         0.0              1.12
# std     153009.56   66344.49         0.0              3.40
# min    1119109.00  241319.00         0.0              1.00
# 25%    1262542.50  362258.50         0.0              1.00
# 50%    1406940.00  425956.00         0.0              1.00
# 75%    1531321.50  478657.00         0.0              1.00
# max    1650203.00  527401.00         0.0            999.00

# %%
orderlines_df.isna().sum()
# Out:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64

# %%
orderlines_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
orderlines_df.nunique()
# Out:
# id                  293983
# id_order            204855
# product_id               1
# product_quantity        67
# sku                   7951
# unit_price           11329
# date                251631
# dtype: int64

# %%
#for identify any pattern
#a)sku: pattern- majority 7 strings (5 with 11 strings, 295  with 5 str, 11646 with 9 str)
orderlines_df['sku'].str.len().nunique()
orderlines_df['sku'].str.len().value_counts()
# Out:
# sku
# 7     282037
# 9      11646
# 5        295
# 11         5
# Name: count, dtype: int64

# %%
#for identify any pattern
orderlines_df['product_id'].nunique()
orderlines_df['product_id'].value_counts()
# Out:
# product_id
# 0    293983
# Name: count, dtype: int64

# %% [markdown]
# **Observation and Action**
# *  product_id: not in use now,only 1 unique     value(0), can be deleted
# *  Max-999(seems to be outlier since mean is 1.12%, also 75% of orders are 1)
# unit_price:should be float
# * Date: should be date format

# %% [markdown]
# ##product

# %%
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %%
products_df.shape

print(f"The number of rows is: {products_df.shape[0]}")
print(f"†he number of columns is:{products_df.shape[1]}")
# Out:
# The number of rows is: 19326
# †he number of columns is:7

# %%
products_df.size
# Out:
# 135282

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
products_df.isna().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
products_df.duplicated().sum()

print(f"The number of duplicated row is:{products_df.duplicated().sum()}")
# Out:
# The number of duplicated row is:8746

# %%
products_df.describe().round(2)
# Out:
#        in_stock
# count  19326.00
# mean       0.11
# std        0.31
# min        0.00
# 25%        0.00
# 50%        0.00
# 75%        0.00
# max        1.00

# %%
products_df.nunique()
# Out:
# sku            10579
# name           10373
# desc            7098
# price           2690
# promo_price     4614
# in_stock           2
# type             126
# dtype: int64

# %%
#for identify any pattern
#a)desc
products_df.loc[products_df['desc'].isna(), :]
# Out:
#              sku                                               name desc  \
# 16126  WDT0211-A  Open - Purple 2TB WD 35 "PC Security Mac hard ...  NaN
# 16128  APP1622-A  Open - Apple Smart Keyboard Pro Keyboard Folio...  NaN
# 17843    PAC2334             Synology DS718 + NAS Server | 10GB RAM  NaN
# 18152  KAN0034-A  Open - Kanex USB-C Gigabit Ethernet Adapter Ma...  NaN
# 18490    HTE0025  Hyper Pearl 1600mAh battery Mini USB Mirror an...  NaN
# 18612    OTT0200    OtterBox External Battery Power Pack 20000 mAHr  NaN
# 18690  HOW0001-A  Open - Honeywell thermostat Lyric zonificador ...  NaN
#
#            price promo_price  in_stock      type
# 16126        107     814.659         0      1298
# 16128  1.568.206   1.568.206         0      1298
# 17843     566.35   5.659.896         0  12175397
# 18152      29.99     237.925         0      1298
# 18490      24.99       22.99         1      1515
# 18612      79.99       56.99         1      1515
# ...

# %% [markdown]
# **Observation and Action**
#
# 1.The number of
#
# *  duplicated value 8746
# * price:
#
# 1. should be float
# 2. missing values
#
# * promo_price:should be float
# * Desc_missing value
#
# *Type: 1.missing value
#        2.Type shuld be numerical as per the data info
#
# *In_stock: values of 0 and 1 to indicate if present in stock or not, can turn to str values if needed for better visualisation.

# %% [markdown]
# #Custom Explanaition

# %% [markdown]
# *How many orders are there?
#
# *How many products are there?
#
# *What period of time do these orders  comprise?
#
# *How many orders are Completed?

# %%
#*How many orders are there? : 226909
orders_df.nunique()

# %%
#*How many products are there? :10579
products_df.nunique()

# %%
#*What period of time do these orders comprise?
orderlines_df['date'].max()
orderlines_df['date'].min()
# Out:
# '2017-01-01 00:07:19'

# %%
import datetime
max_date= datetime.datetime(2018,3,14)
min_date= datetime.datetime(2017,1,1)
date_diff= max_date-min_date
print(f"First order date is {min_date} \n Last order date is {max_date}" )
print(date_diff)
# Out:
# First order date is 2017-01-01 00:00:00
#  Last order date is 2018-03-14 00:00:00
# 437 days, 0:00:00

# %%
#How many orders are Completed? :46605
orders_df[orders_df['state']=='Completed']['order_id'].count()
# Out:
# np.int64(46605)
